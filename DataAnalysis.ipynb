# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('treebank')
"""
punkt: This NLTK resource is a pre-trained model used for tokenizing text 
into sentences or words. It's useful for breaking down paragraphs or documents into meaningful linguistic units.

stopwords: NLTK provides lists of stopwords for various languages. 
Stopwords are common words (like "and", "the", "in") that are often filtered out from text data because 
they typically do not contribute much to the meaning of the text.

wordnet: WordNet is a lexical database for the English language. 
It groups English words into sets of synonyms (synsets), provides short definitions, and records the various 
semantic relationships between these sets.

averaged_perceptron_tagger: This NLTK resource is a part-of-speech (POS) 
tagger based on the averaged perceptron algorithm. It assigns grammatical 
categories (like noun, verb, adjective) to words in a sentence, which is useful for syntax and semantic analysis.

maxent_ne_chunker: This is a named entity chunker trained on the CoNLL 2002 Dutch 
and Spanish data sets. It identifies named entities (like names of people, organizations, locations) in text.

words: This NLTK corpus contains a list of words in various languages. 
It's useful for tasks that require a large vocabulary set or dictionary.

treebank: The Penn Treebank Project provides a large annotated corpus of English, 
including syntactic and semantic annotations. It's used for training and testing various
natural language processing tools and algorithms.
"""
# Out:
# [nltk_data] Downloading package punkt to /home/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/user/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /home/user/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /home/user/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package treebank to /home/user/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# '\npunkt: This NLTK resource is a pre-trained model used for tokenizing text \ninto sentences or words. It\'s useful for breaking down paragraphs or documents into meaningful linguistic units.\n\nstopwords: NLTK provides lists of stopwords for various languages. \nStopwords are common words (like "and", "the", "in") that are often filtered out from text data because \nthey typically do not contribute much to the meaning of the text.\n\nwordnet: WordNet is a lexical database for the English language. \nIt groups English words into sets of synonyms (synsets), provides short definitions, and records the various \nsemantic relationships between these sets.\n\naveraged_perceptron_tagger: This NLTK resource is a part-of-speech (POS) \ntagger based on the averaged perceptron algorithm. It assigns grammatical \ncategories (like noun, verb, adjective) to words in a sentence, which is useful for syntax and semantic analysis.\n\nmaxent_ne_chunker: This is a named entity chunker trained on the CoNLL 2002 Dutch \nand Spanish data sets. It identifies named entities (like names of people, organizations, locations) in text.\n\nwords: This NLTK corpus contains a list of words in various languages. \nIt\'s useful for tasks that require a large vocabulary set or dictionary.\n\ntreebank: The Penn Treebank Project provides a large annotated corpus of English, \nincluding syntactic and semantic annotations. It\'s used for training and testing various\nnatural language processing tools and algorithms.\n'

# %%
df=pd.read_csv("train_sent_emo.csv")

# %%
df.head()
# Out:
#    Sr No.                                          Utterance          Speaker  \
# 0       1  also I was the point person on my company’s tr...         Chandler
# 1       2                   You must’ve had your hands full.  The Interviewer
# 2       3                            That I did. That I did.         Chandler
# 3       4      So let’s talk a little bit about your duties.  The Interviewer
# 4       5                             My duties?  All right.         Chandler
#
#     Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# 0   neutral   neutral            0             0       8       21
# 1   neutral   neutral            0             1       8       21
# 2   neutral   neutral            0             2       8       21
# 3   neutral   neutral            0             3       8       21
# 4  surprise  positive            0             4       8       21
#
#       StartTime       EndTime
# 0  00:16:16,059  00:16:21,731
# 1  00:16:21,940  00:16:23,442
# 2  00:16:23,442  00:16:26,389
# 3  00:16:26,820  00:16:29,572
# 4  00:16:34,452  00:16:40,917

# %%
list(df.columns)
# Out:
# ['Sr No.',
#  'Utterance',
#  'Speaker',
#  'Emotion',
#  'Sentiment',
#  'Dialogue_ID',
#  'Utterance_ID',
#  'Season',
#  'Episode',
#  'StartTime',
#  'EndTime']

# %%
df.shape
# Out:
# (9989, 11)

# %%
df.dtypes
# Out:
# Sr No.           int64
# Utterance       object
# Speaker         object
# Emotion         object
# Sentiment       object
# Dialogue_ID      int64
# Utterance_ID     int64
# Season           int64
# Episode          int64
# StartTime       object
# EndTime         object
# dtype: object

# %%
df.memory_usage()
# Out:
# Index              80
# Sr No.          79912
# Utterance       79912
# Speaker         79912
# Emotion         79912
# Sentiment       79912
# Dialogue_ID     79912
# Utterance_ID    79912
# Season          79912
# Episode         79912
# StartTime       79912
# EndTime         79912
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
"""

Data Description:

Sr No.: This is the unique index number for each row in the dataset.

Utterance: This refers to the actual spoken words of a character in a dialogue.

Speaker: This is the name of the person who spoke the utterance.

Emotion: This describes the emotional state or expression conveyed in the utterance.

Sentiment: This categorizes the overall opinion expressed in the utterance as positive, negative, or neutral.

Dialogue_ID: This is a unique identifier for each conversation or dialogue session.

Utterance_ID: This is a unique identifier for each individual utterance within a conversation.

Season: If applicable, this indicates the season number of the show or series.

Episode: If applicable, this indicates the episode number within a season.

StartTime: This is the timestamp or start time of the utterance within the episode.

EndTime: This is the timestamp or end time of the utterance within the episode.

Using Columns we can perform some operations to achecve the followning task 

We can identify which characters or speakers are the most active or have the most lines in the dialogue.
It helps us understand the emotions and opinions expressed by different characters.
Emotion and Sentiment Analysis:

We can explore how emotions and sentiments change across different episodes or seasons of the show.
It allows us to detect patterns in how sentiments or emotions evolve throughout the series.
Dialogue Structure:

Analyzing the structure and flow of dialogues based on Dialogue_ID and Utterance_ID helps us understand how conversations progress.
We can observe how dialogues develop within episodes and across multiple seasons.
Temporal Analysis:

We can investigate if there are any time-based patterns in the emotions or sentiments expressed during dialogues.
Comparing emotions or sentiments at different start and end times of episodes gives insights into temporal dynamics.
Season and Episode Patterns:

By analyzing emotions or sentiments across seasons and episodes, we can identify significant changes or trends.
It helps us track the development of characters or themes over the course of the serie
"""
# Out:
# '\n\nData Description:\n\nSr No.: This is the unique index number for each row in the dataset.\n\nUtterance: This refers to the actual spoken words of a character in a dialogue.\n\nSpeaker: This is the name of the person who spoke the utterance.\n\nEmotion: This describes the emotional state or expression conveyed in the utterance.\n\nSentiment: This categorizes the overall opinion expressed in the utterance as positive, negative, or neutral.\n\nDialogue_ID: This is a unique identifier for each conversation or dialogue session.\n\nUtterance_ID: This is a unique identifier for each individual utterance within a conversation.\n\nSeason: If applicable, this indicates the season number of the show or series.\n\nEpisode: If applicable, this indicates the episode number within a season.\n\nStartTime: This is the timestamp or start time of the utterance within the episode.\n\nEndTime: This is the timestamp or end time of the utterance within the episode.\n\nUsing Columns we can perform some operations to achecve the followning task \n\nWe can identify which characters or speakers are the most active or have the most lines in the dialogue.\nIt helps us understand the emotions and opinions expressed by different characters.\nEmotion and Sentiment Analysis:\n\nWe can explore how emotions and sentiments change across different episodes or seasons of the show.\nIt allows us to detect patterns in how sentiments or emotions evolve throughout the series.\nDialogue Structure:\n\nAnalyzing the structure and flow of dialogues based on Dialogue_ID and Utterance_ID helps us understand how conversations progress.\nWe can observe how dialogues develop within episodes and across multiple seasons.\nTemporal Analysis:\n\nWe can investigate if there are any time-based patterns in the emotions or sentiments expressed during dialogues.\nComparing emotions or sentiments at different start and end times of episodes gives insights into temporal dynamics.\nSeason and Episode Patterns:\n\nBy analyzing emotions or sentiments across seasons and episodes, we can identify significant changes or trends.\nIt helps us track the development of characters or themes over the course of the serie\n'

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Sr No.  Dialogue_ID  Utterance_ID       Season      Episode
# count   9989.000000  9989.000000    9989.00000  9989.000000  9989.000000
# mean    5262.373511   526.549304       6.14516     4.853739    12.697167
# std     3032.169169   302.464741       4.96027     2.389599     7.220392
# min        1.000000     0.000000       0.00000     1.000000     1.000000
# 25%     2641.000000   261.000000       2.00000     3.000000     6.000000
# 50%     5267.000000   531.000000       5.00000     5.000000    12.000000
# 75%     7891.000000   795.000000       9.00000     7.000000    19.000000
# max    10478.000000  1038.000000      23.00000     9.000000    25.000000

# %%
columns_info = df.dtypes.to_dict()
print(columns_info)
# Out:
# {'Sr No.': dtype('int64'), 'Utterance': dtype('O'), 'Speaker': dtype('O'), 'Emotion': dtype('O'), 'Sentiment': dtype('O'), 'Dialogue_ID': dtype('int64'), 'Utterance_ID': dtype('int64'), 'Season': dtype('int64'), 'Episode': dtype('int64'), 'StartTime': dtype('O'), 'EndTime': dtype('O')}

# %%
null_values = df.isnull().sum().to_dict()
print(null_values)
# Out:
# {'Sr No.': 0, 'Utterance': 0, 'Speaker': 0, 'Emotion': 0, 'Sentiment': 0, 'Dialogue_ID': 0, 'Utterance_ID': 0, 'Season': 0, 'Episode': 0, 'StartTime': 0, 'EndTime': 0}

# %%
# Describe all columns including categorical and numeric
description = df.describe(include='all').to_dict()
print(description)
# Out:
# {'Sr No.': {'count': 9989.0, 'unique': nan, 'top': nan, 'freq': nan, 'mean': 5262.3735108619485, 'std': 3032.1691693883513, 'min': 1.0, '25%': 2641.0, '50%': 5267.0, '75%': 7891.0, 'max': 10478.0}, 'Utterance': {'count': 9989, 'unique': 8931, 'top': 'Hey!', 'freq': 79, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}, 'Speaker': {'count': 9989, 'unique': 260, 'top': 'Joey', 'freq': 1510, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}, 'Emotion': {'count': 9989, 'unique': 7, 'top': 'neutral', 'freq': 4710, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}, 'Sentiment': {'count': 9989, 'unique': 3, 'top': 'neutral', 'freq': 4710, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}, 'Dialogue_ID': {'count': 9989.0, 'unique': nan, 'top': nan, 'freq': nan, 'mean': 526.5493042346582, 'std': 302.46474108610954, 'min': 0.0, '25%': 261.0, '50%': 531.0, '75%': 795.0, 'max': 1038.0}, 'Utterance_ID': {'count': 9989.0, 'unique': nan, 'top': nan, 'freq': nan, 'mean': 6.145159675643208, 'std': 4.960269849454451, 'min': 0.0, '25%': 2.0, '50%': 5.0, '75%': 9.0, 'max': 23.0}, 'Season': {'count': 9989.0, 'unique': nan, 'top': nan, 'freq': nan, 'mean': 4.853739113024327, 'std': 2.3895990259075823, 'min': 1.0, '25%': 3.0, '50%': 5.0, '75%': 7.0, 'max': 9.0}, 'Episode': {'count': 9989.0, 'unique': nan, 'top': nan, 'freq': nan, 'mean': 12.69716688357193, 'std': 7.220391530027724, 'min': 1.0, '25%': 6.0, '50%': 12.0, '75%': 19.0, 'max': 25.0}, 'StartTime': {'count': 9989, 'unique': 9008, 'top': '00:08:47,485', 'freq': 4, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}, 'EndTime': {'count': 9989, 'unique': 8959, 'top': '00:06:01,818', 'freq': 5, 'mean': nan, 'std': nan, 'min': nan, '25%': nan, '50%': nan, '75%': nan, 'max': nan}}

# %%
duplicate_rows=df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Sr No., Utterance, Speaker, Emotion, Sentiment, Dialogue_ID, Utterance_ID, Season, Episode, StartTime, EndTime]
# Index: []

# %%
df
# Out:
#       Sr No.                                          Utterance  \
# 0          1  also I was the point person on my company’s tr...
# 1          2                   You must’ve had your hands full.
# 2          3                            That I did. That I did.
# 3          4      So let’s talk a little bit about your duties.
# 4          5                             My duties?  All right.
# 5          6  Now you’ll be heading a whole division, so you...
# 6          7                                             I see.
# 7          8  But there’ll be perhaps 30 people under you so...
# 8          9                                      Good to know.
# 9         10                              We can go into detail
# 10        11                             No don’t I beg of you!
# 11        12  All right then, we’ll have a definite answer f...
# 12        13                                           Really?!
# 13        14                         Absolutely.  You can relax
# 14        15  But then who? The waitress I went out with las...
# 15        16                               You know? Forget it!
# 16        17  No-no-no-no, no! Who, who were you talking about?
# 17        18           No, I-I-I-I don't, I actually don't know
# 18        19                                                Ok!
# 19        20                                 All right, well...
# 20        23                                        Yeah, sure!
# 21        24                                          Hey, Mon.
# 22        25  Hey-hey-hey. You wanna hear something that sucks.
# 23        26                                         Do I ever.
# 24        27           Chris says they’re closing down the bar.
# 25        28                                            No way!
# 26        29  Yeah, apparently they’re turning it into some ...
# 27        30      Just coffee! Where are we gonna hang out now?
# 28        31                                            Got me.
# 29        32                                  Can I get a beer.
# ...      ...                                                ...
# 9959   10449                            The money will turn up!
# 9960   10450         People will always wanna invest in movies!
# 9961   10451                       Hey, you're not rich are ya?
# 9962   10452                                                No!
# 9963   10453  Eh, worth a shot.  Look Joey, let me know wher...
# 9964   10454                   Hey pal, are you Joey Tribbiani?
# 9965   10455                                              Yeah.
# 9966   10456                             These got left for ya.
# 9967   10457       Thanks.   Congratulations on your big break.
# 9968   10458              Rachel, do you have any muffins left?
# 9969   10459                         Yeah, I forget which ones.
# 9970   10460  Oh, you're busy, that's ok, I'll get it. Anybo...
# 9971   10461                                               Hey.
# 9972   10462                                               Hey!
# 9973   10463                                   So how was Joan?
# 9974   10464                               I broke up with her.
# 9975   10465   Don’t tell me, because of the big nostril thing?
# 9976   10466  They were huge. When she sneezed, bats flew ou...
# 9977   10467                  Come on, they were not that huge.
# 9978   10468  I'm tellin' you, she leaned back; I could see ...
# 9979   10469  How many perfectly fine women are you gonna re...
# 9980   10470                                  Hold it, hold it.
# 9981   10471            I gotta side with Chandler on this one.
# 9982   10472  When I first moved to the city, I went out a c...
# 9983   10473                                   It made me nuts.
# 9984   10474                                         You or me?
# 9985   10475  I got it. Uh, Joey, women don't have Adam's ap...
# 9986   10476               You guys are messing with me, right?
# 9987   10477                                              Yeah.
# 9988   10478  That was a good one. For a second there, I was...
#
#               Speaker   Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  \
# 0            Chandler   neutral   neutral            0             0       8
# 1     The Interviewer   neutral   neutral            0             1       8
# 2            Chandler   neutral   neutral            0             2       8
# 3     The Interviewer   neutral   neutral            0             3       8
# 4            Chandler  surprise  positive            0             4       8
# 5     The Interviewer   neutral   neutral            0             5       8
# 6            Chandler   neutral   neutral            0             6       8
# 7     The Interviewer   neutral   neutral            0             7       8
# 8            Chandler   neutral   neutral            0             8       8
# 9     The Interviewer   neutral   neutral            0             9       8
# 10           Chandler      fear  negative            0            10       8
# 11    The Interviewer   neutral   neutral            0            11       8
# 12           Chandler  surprise  positive            0            12       8
# 13    The Interviewer   neutral   neutral            0            13       8
# 14               Joey  surprise  negative            1             0       9
# 15             Rachel   sadness  negative            1             1       9
# 16               Joey  surprise  negative            1             2       9
# 17             Rachel      fear  negative            1             3       9
# 18               Joey   neutral   neutral            1             4       9
# 19               Joey   neutral   neutral            1             5       9
# 20             Rachel   neutral   neutral            1             8       9
# 21           Chandler   neutral   neutral            2             0       3
# 22             Monica   neutral   neutral            2             1       3
# 23           Chandler       joy  positive            2             2       3
# 24             Monica   sadness  negative            2             3       3
# 25           Chandler  surprise  negative            2             4       3
# 26             Monica   neutral   neutral            2             5       3
# 27           Chandler   disgust  negative            2             6       3
# 28             Monica   sadness  negative            2             7       3
# 29           Chandler   neutral   neutral            2             8       3
# ...               ...       ...       ...          ...           ...     ...
# 9959          Stanley   neutral   neutral         1036            12       5
# 9960          Stanley   neutral   neutral         1036            13       5
# 9961          Stanley   neutral   neutral         1036            14       5
# 9962             Joey     anger  negative         1036            15       5
# 9963          Stanley   neutral   neutral         1036            16       5
# 9964         The Grip   neutral   neutral         1036            17       5
# 9965             Joey   neutral   neutral         1036            18       5
# 9966         The Grip   neutral   neutral         1036            19       5
# 9967             Joey   sadness  negative         1036            20       5
# 9968            Julie   neutral   neutral         1037             0       2
# 9969           Rachel   neutral   neutral         1037             1       2
# 9970            Julie   neutral   neutral         1037             2       2
# 9971         Chandler   neutral   neutral         1038             0       2
# 9972              All       joy  positive         1038             1       2
# 9973           Monica   neutral   neutral         1038             2       2
# 9974         Chandler   neutral   neutral         1038             3       2
# 9975             Ross  surprise  negative         1038             4       2
# 9976         Chandler   disgust  negative         1038             5       2
# 9977           Rachel   neutral   neutral         1038             6       2
# 9978         Chandler   disgust  negative         1038             7       2
# 9979           Monica  surprise  negative         1038             8       2
# 9980             Joey   neutral   neutral         1038             9       2
# 9981             Joey   neutral   neutral         1038            10       2
# 9982             Joey   disgust  negative         1038            11       2
# 9983             Joey   disgust  negative         1038            12       2
# 9984         Chandler   neutral   neutral         1038            13       2
# 9985             Ross   neutral   neutral         1038            14       2
# 9986             Joey  surprise  positive         1038            15       2
# 9987              All   neutral   neutral         1038            16       2
# 9988             Joey       joy  positive         1038            17       2
#
#       Episode     StartTime       EndTime
# 0          21  00:16:16,059  00:16:21,731
# 1          21  00:16:21,940  00:16:23,442
# 2          21  00:16:23,442  00:16:26,389
# 3          21  00:16:26,820  00:16:29,572
# 4          21  00:16:34,452  00:16:40,917
# 5          21  00:16:41,126  00:16:44,337
# 6          21  00:16:48,800  00:16:51,886
# 7          21  00:16:48,800  00:16:54,514
# 8          21  00:16:59,477  00:17:00,478
# 9          21  00:17:00,478  00:17:02,719
# 10         21  00:17:02,856  00:17:04,858
# 11         21  00:17:05,025  00:17:13,324
# 12         21  00:17:13,491  00:17:16,536
# 13         21  00:17:17,579  00:17:20,707
# 14         23  00:36:40,364  00:36:42,824
# 15         23  00:36:44,368  00:36:46,578
# 16         23  00:36:44,368  00:36:49,122
# 17         23  00:36:49,290  00:36:51,791
# 18         23  00:36:52,376  00:36:53,543
# 19         23  00:36:53,545  00:36:55,000
# 20         23   0:36:59,425   0:37:01,439
# 21          6  00:05:50,350  00:05:51,433
# 22          6   0:05:52,435   0:05:53,897
# 23          6   0:05:53,897   0:05:55,743
# 24          6   0:05:57,023   0:05:58,734
# 25          6   0:05:58,734   0:05:59,774
# 26          6  00:05:59,942  00:06:02,152
# 27          6  00:06:02,362  00:06:07,157
# 28          6  00:06:04,489  00:06:07,157
# 29          6   0:06:07,367   0:06:08,035
# ...       ...           ...           ...
# 9959       22   0:19:47,050   0:19:48,700
# 9960       22   0:19:48,770   0:19:50,532
# 9961       22   0:19:50,532   0:19:52,248
# 9962       22  00:19:52,441  00:19:54,192
# 9963       22  00:19:52,441  00:19:59,322
# 9964       22   0:20:01,909   0:20:04,011
# 9965       22   0:20:04,011   0:20:04,641
# 9966       22  00:20:04,828  00:20:06,245
# 9967       22  00:20:06,496  00:20:12,877
# 9968        2   0:02:44,706   0:02:46,098
# 9969        2   0:02:46,098   0:02:47,672
# 9970        2  00:02:47,792  00:02:52,963
# 9971        3   0:00:05,130   0:00:05,673
# 9972        3   0:00:05,673   0:00:06,967
# 9973        3  00:00:07,173  00:00:08,173
# 9974        3  00:00:08,341  00:00:09,341
# 9975        3  00:00:11,136  00:00:13,887
# 9976        3  00:00:15,015  00:00:20,060
# 9977        3  00:00:21,021  00:00:22,855
# 9978        3  00:00:23,106  00:00:26,358
# 9979        3  00:00:28,319  00:00:32,573
# 9980        3   0:00:32,824   0:00:33,456
# 9981        3   0:00:33,456   0:00:35,556
# 9982        3  00:00:35,744  00:00:44,334
# 9983        3  00:00:45,462  00:00:46,587
# 9984        3  00:00:48,173  00:00:50,799
# 9985        3  00:00:51,009  00:00:53,594
# 9986        3  00:01:00,518  00:01:03,520
# 9987        3  00:01:05,398  00:01:07,274
# 9988        3  00:01:08,401  00:01:12,071
#
# [9989 rows x 11 columns]

# %%
data=df.copy()

# %%
data[['StartTime','EndTime']].head()
# Out:
#       StartTime       EndTime
# 0  00:16:16,059  00:16:21,731
# 1  00:16:21,940  00:16:23,442
# 2  00:16:23,442  00:16:26,389
# 3  00:16:26,820  00:16:29,572
# 4  00:16:34,452  00:16:40,917

# %%
data['StartTime']=df['StartTime'].str.replace(',','.')
data['EndTime']=df['EndTime'].str.replace(',','.')

# %%
data
# Out:
#       Sr No.                                          Utterance  \
# 0          1  also I was the point person on my company’s tr...
# 1          2                   You must’ve had your hands full.
# 2          3                            That I did. That I did.
# 3          4      So let’s talk a little bit about your duties.
# 4          5                             My duties?  All right.
# 5          6  Now you’ll be heading a whole division, so you...
# 6          7                                             I see.
# 7          8  But there’ll be perhaps 30 people under you so...
# 8          9                                      Good to know.
# 9         10                              We can go into detail
# 10        11                             No don’t I beg of you!
# 11        12  All right then, we’ll have a definite answer f...
# 12        13                                           Really?!
# 13        14                         Absolutely.  You can relax
# 14        15  But then who? The waitress I went out with las...
# 15        16                               You know? Forget it!
# 16        17  No-no-no-no, no! Who, who were you talking about?
# 17        18           No, I-I-I-I don't, I actually don't know
# 18        19                                                Ok!
# 19        20                                 All right, well...
# 20        23                                        Yeah, sure!
# 21        24                                          Hey, Mon.
# 22        25  Hey-hey-hey. You wanna hear something that sucks.
# 23        26                                         Do I ever.
# 24        27           Chris says they’re closing down the bar.
# 25        28                                            No way!
# 26        29  Yeah, apparently they’re turning it into some ...
# 27        30      Just coffee! Where are we gonna hang out now?
# 28        31                                            Got me.
# 29        32                                  Can I get a beer.
# ...      ...                                                ...
# 9959   10449                            The money will turn up!
# 9960   10450         People will always wanna invest in movies!
# 9961   10451                       Hey, you're not rich are ya?
# 9962   10452                                                No!
# 9963   10453  Eh, worth a shot.  Look Joey, let me know wher...
# 9964   10454                   Hey pal, are you Joey Tribbiani?
# 9965   10455                                              Yeah.
# 9966   10456                             These got left for ya.
# 9967   10457       Thanks.   Congratulations on your big break.
# 9968   10458              Rachel, do you have any muffins left?
# 9969   10459                         Yeah, I forget which ones.
# 9970   10460  Oh, you're busy, that's ok, I'll get it. Anybo...
# 9971   10461                                               Hey.
# 9972   10462                                               Hey!
# 9973   10463                                   So how was Joan?
# 9974   10464                               I broke up with her.
# 9975   10465   Don’t tell me, because of the big nostril thing?
# 9976   10466  They were huge. When she sneezed, bats flew ou...
# 9977   10467                  Come on, they were not that huge.
# 9978   10468  I'm tellin' you, she leaned back; I could see ...
# 9979   10469  How many perfectly fine women are you gonna re...
# 9980   10470                                  Hold it, hold it.
# 9981   10471            I gotta side with Chandler on this one.
# 9982   10472  When I first moved to the city, I went out a c...
# 9983   10473                                   It made me nuts.
# 9984   10474                                         You or me?
# 9985   10475  I got it. Uh, Joey, women don't have Adam's ap...
# 9986   10476               You guys are messing with me, right?
# 9987   10477                                              Yeah.
# 9988   10478  That was a good one. For a second there, I was...
#
#               Speaker   Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  \
# 0            Chandler   neutral   neutral            0             0       8
# 1     The Interviewer   neutral   neutral            0             1       8
# 2            Chandler   neutral   neutral            0             2       8
# 3     The Interviewer   neutral   neutral            0             3       8
# 4            Chandler  surprise  positive            0             4       8
# 5     The Interviewer   neutral   neutral            0             5       8
# 6            Chandler   neutral   neutral            0             6       8
# 7     The Interviewer   neutral   neutral            0             7       8
# 8            Chandler   neutral   neutral            0             8       8
# 9     The Interviewer   neutral   neutral            0             9       8
# 10           Chandler      fear  negative            0            10       8
# 11    The Interviewer   neutral   neutral            0            11       8
# 12           Chandler  surprise  positive            0            12       8
# 13    The Interviewer   neutral   neutral            0            13       8
# 14               Joey  surprise  negative            1             0       9
# 15             Rachel   sadness  negative            1             1       9
# 16               Joey  surprise  negative            1             2       9
# 17             Rachel      fear  negative            1             3       9
# 18               Joey   neutral   neutral            1             4       9
# 19               Joey   neutral   neutral            1             5       9
# 20             Rachel   neutral   neutral            1             8       9
# 21           Chandler   neutral   neutral            2             0       3
# 22             Monica   neutral   neutral            2             1       3
# 23           Chandler       joy  positive            2             2       3
# 24             Monica   sadness  negative            2             3       3
# 25           Chandler  surprise  negative            2             4       3
# 26             Monica   neutral   neutral            2             5       3
# 27           Chandler   disgust  negative            2             6       3
# 28             Monica   sadness  negative            2             7       3
# 29           Chandler   neutral   neutral            2             8       3
# ...               ...       ...       ...          ...           ...     ...
# 9959          Stanley   neutral   neutral         1036            12       5
# 9960          Stanley   neutral   neutral         1036            13       5
# 9961          Stanley   neutral   neutral         1036            14       5
# 9962             Joey     anger  negative         1036            15       5
# 9963          Stanley   neutral   neutral         1036            16       5
# 9964         The Grip   neutral   neutral         1036            17       5
# 9965             Joey   neutral   neutral         1036            18       5
# 9966         The Grip   neutral   neutral         1036            19       5
# 9967             Joey   sadness  negative         1036            20       5
# 9968            Julie   neutral   neutral         1037             0       2
# 9969           Rachel   neutral   neutral         1037             1       2
# 9970            Julie   neutral   neutral         1037             2       2
# 9971         Chandler   neutral   neutral         1038             0       2
# 9972              All       joy  positive         1038             1       2
# 9973           Monica   neutral   neutral         1038             2       2
# 9974         Chandler   neutral   neutral         1038             3       2
# 9975             Ross  surprise  negative         1038             4       2
# 9976         Chandler   disgust  negative         1038             5       2
# 9977           Rachel   neutral   neutral         1038             6       2
# 9978         Chandler   disgust  negative         1038             7       2
# 9979           Monica  surprise  negative         1038             8       2
# 9980             Joey   neutral   neutral         1038             9       2
# 9981             Joey   neutral   neutral         1038            10       2
# 9982             Joey   disgust  negative         1038            11       2
# 9983             Joey   disgust  negative         1038            12       2
# 9984         Chandler   neutral   neutral         1038            13       2
# 9985             Ross   neutral   neutral         1038            14       2
# 9986             Joey  surprise  positive         1038            15       2
# 9987              All   neutral   neutral         1038            16       2
# 9988             Joey       joy  positive         1038            17       2
#
#       Episode     StartTime       EndTime
# 0          21  00:16:16.059  00:16:21.731
# 1          21  00:16:21.940  00:16:23.442
# 2          21  00:16:23.442  00:16:26.389
# 3          21  00:16:26.820  00:16:29.572
# 4          21  00:16:34.452  00:16:40.917
# 5          21  00:16:41.126  00:16:44.337
# 6          21  00:16:48.800  00:16:51.886
# 7          21  00:16:48.800  00:16:54.514
# 8          21  00:16:59.477  00:17:00.478
# 9          21  00:17:00.478  00:17:02.719
# 10         21  00:17:02.856  00:17:04.858
# 11         21  00:17:05.025  00:17:13.324
# 12         21  00:17:13.491  00:17:16.536
# 13         21  00:17:17.579  00:17:20.707
# 14         23  00:36:40.364  00:36:42.824
# 15         23  00:36:44.368  00:36:46.578
# 16         23  00:36:44.368  00:36:49.122
# 17         23  00:36:49.290  00:36:51.791
# 18         23  00:36:52.376  00:36:53.543
# 19         23  00:36:53.545  00:36:55.000
# 20         23   0:36:59.425   0:37:01.439
# 21          6  00:05:50.350  00:05:51.433
# 22          6   0:05:52.435   0:05:53.897
# 23          6   0:05:53.897   0:05:55.743
# 24          6   0:05:57.023   0:05:58.734
# 25          6   0:05:58.734   0:05:59.774
# 26          6  00:05:59.942  00:06:02.152
# 27          6  00:06:02.362  00:06:07.157
# 28          6  00:06:04.489  00:06:07.157
# 29          6   0:06:07.367   0:06:08.035
# ...       ...           ...           ...
# 9959       22   0:19:47.050   0:19:48.700
# 9960       22   0:19:48.770   0:19:50.532
# 9961       22   0:19:50.532   0:19:52.248
# 9962       22  00:19:52.441  00:19:54.192
# 9963       22  00:19:52.441  00:19:59.322
# 9964       22   0:20:01.909   0:20:04.011
# 9965       22   0:20:04.011   0:20:04.641
# 9966       22  00:20:04.828  00:20:06.245
# 9967       22  00:20:06.496  00:20:12.877
# 9968        2   0:02:44.706   0:02:46.098
# 9969        2   0:02:46.098   0:02:47.672
# 9970        2  00:02:47.792  00:02:52.963
# 9971        3   0:00:05.130   0:00:05.673
# 9972        3   0:00:05.673   0:00:06.967
# 9973        3  00:00:07.173  00:00:08.173
# 9974        3  00:00:08.341  00:00:09.341
# 9975        3  00:00:11.136  00:00:13.887
# 9976        3  00:00:15.015  00:00:20.060
# 9977        3  00:00:21.021  00:00:22.855
# 9978        3  00:00:23.106  00:00:26.358
# 9979        3  00:00:28.319  00:00:32.573
# 9980        3   0:00:32.824   0:00:33.456
# 9981        3   0:00:33.456   0:00:35.556
# 9982        3  00:00:35.744  00:00:44.334
# 9983        3  00:00:45.462  00:00:46.587
# 9984        3  00:00:48.173  00:00:50.799
# 9985        3  00:00:51.009  00:00:53.594
# 9986        3  00:01:00.518  00:01:03.520
# 9987        3  00:01:05.398  00:01:07.274
# 9988        3  00:01:08.401  00:01:12.071
#
# [9989 rows x 11 columns]

# %%
data['StartTime']=pd.to_datetime(data['StartTime'],format='%H:%M:%S.%f')
data['EndTime']=pd.to_datetime(data['EndTime'],format="%H:%M:%S.%f")

# %%
#Calculate duration and add as new column
data['Duration'] = data['EndTime'] - data['StartTime']

# %%
data.head()
# Out:
#    Sr No.                                          Utterance          Speaker  \
# 0       1  also I was the point person on my company’s tr...         Chandler
# 1       2                   You must’ve had your hands full.  The Interviewer
# 2       3                            That I did. That I did.         Chandler
# 3       4      So let’s talk a little bit about your duties.  The Interviewer
# 4       5                             My duties?  All right.         Chandler
#
#     Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# 0   neutral   neutral            0             0       8       21
# 1   neutral   neutral            0             1       8       21
# 2   neutral   neutral            0             2       8       21
# 3   neutral   neutral            0             3       8       21
# 4  surprise  positive            0             4       8       21
#
#                 StartTime                 EndTime        Duration
# 0 1900-01-01 00:16:16.059 1900-01-01 00:16:21.731 00:00:05.672000
# 1 1900-01-01 00:16:21.940 1900-01-01 00:16:23.442 00:00:01.502000
# 2 1900-01-01 00:16:23.442 1900-01-01 00:16:26.389 00:00:02.947000
# 3 1900-01-01 00:16:26.820 1900-01-01 00:16:29.572 00:00:02.752000
# 4 1900-01-01 00:16:34.452 1900-01-01 00:16:40.917 00:00:06.465000

# %%
data['Duration_Minutes'] = data['Duration'].dt.total_seconds() / 60

# %%
data.drop(['Sr No.', 'Dialogue_ID', 'Utterance_ID', 'Season', 'Episode', 'StartTime', 'EndTime', 'Duration'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                            Utterance          Speaker  \
# 0  also I was the point person on my company’s tr...         Chandler
# 1                   You must’ve had your hands full.  The Interviewer
# 2                            That I did. That I did.         Chandler
# 3      So let’s talk a little bit about your duties.  The Interviewer
# 4                             My duties?  All right.         Chandler
#
#     Emotion Sentiment  Duration_Minutes
# 0   neutral   neutral          0.094533
# 1   neutral   neutral          0.025033
# 2   neutral   neutral          0.049117
# 3   neutral   neutral          0.045867
# 4  surprise  positive          0.107750

# %%
dfa=data.copy()
dfa=dfa.drop_duplicates()

# %%
print(dfa)
# Out:
#                                               Utterance          Speaker  \
# 0     also I was the point person on my company’s tr...         Chandler
# 1                      You must’ve had your hands full.  The Interviewer
# 2                               That I did. That I did.         Chandler
# 3         So let’s talk a little bit about your duties.  The Interviewer
# 4                                My duties?  All right.         Chandler
# 5     Now you’ll be heading a whole division, so you...  The Interviewer
# 6                                                I see.         Chandler
# 7     But there’ll be perhaps 30 people under you so...  The Interviewer
# 8                                         Good to know.         Chandler
# 9                                 We can go into detail  The Interviewer
# 10                               No don’t I beg of you!         Chandler
# 11    All right then, we’ll have a definite answer f...  The Interviewer
# 12                                             Really?!         Chandler
# 13                           Absolutely.  You can relax  The Interviewer
# 14    But then who? The waitress I went out with las...             Joey
# 15                                 You know? Forget it!           Rachel
# 16    No-no-no-no, no! Who, who were you talking about?             Joey
# 17             No, I-I-I-I don't, I actually don't know           Rachel
# 18                                                  Ok!             Joey
# 19                                   All right, well...             Joey
# 20                                          Yeah, sure!           Rachel
# 21                                            Hey, Mon.         Chandler
# 22    Hey-hey-hey. You wanna hear something that sucks.           Monica
# 23                                           Do I ever.         Chandler
# 24             Chris says they’re closing down the bar.           Monica
# 25                                              No way!         Chandler
# 26    Yeah, apparently they’re turning it into some ...           Monica
# 27        Just coffee! Where are we gonna hang out now?         Chandler
# 28                                              Got me.           Monica
# 29                                    Can I get a beer.         Chandler
# ...                                                 ...              ...
# 9959                            The money will turn up!          Stanley
# 9960         People will always wanna invest in movies!          Stanley
# 9961                       Hey, you're not rich are ya?          Stanley
# 9962                                                No!             Joey
# 9963  Eh, worth a shot.  Look Joey, let me know wher...          Stanley
# 9964                   Hey pal, are you Joey Tribbiani?         The Grip
# 9965                                              Yeah.             Joey
# 9966                             These got left for ya.         The Grip
# 9967       Thanks.   Congratulations on your big break.             Joey
# 9968              Rachel, do you have any muffins left?            Julie
# 9969                         Yeah, I forget which ones.           Rachel
# 9970  Oh, you're busy, that's ok, I'll get it. Anybo...            Julie
# 9971                                               Hey.         Chandler
# 9972                                               Hey!              All
# 9973                                   So how was Joan?           Monica
# 9974                               I broke up with her.         Chandler
# 9975   Don’t tell me, because of the big nostril thing?             Ross
# 9976  They were huge. When she sneezed, bats flew ou...         Chandler
# 9977                  Come on, they were not that huge.           Rachel
# 9978  I'm tellin' you, she leaned back; I could see ...         Chandler
# 9979  How many perfectly fine women are you gonna re...           Monica
# 9980                                  Hold it, hold it.             Joey
# 9981            I gotta side with Chandler on this one.             Joey
# 9982  When I first moved to the city, I went out a c...             Joey
# 9983                                   It made me nuts.             Joey
# 9984                                         You or me?         Chandler
# 9985  I got it. Uh, Joey, women don't have Adam's ap...             Ross
# 9986               You guys are messing with me, right?             Joey
# 9987                                              Yeah.              All
# 9988  That was a good one. For a second there, I was...             Joey
#
#        Emotion Sentiment  Duration_Minutes
# 0      neutral   neutral          0.094533
# 1      neutral   neutral          0.025033
# 2      neutral   neutral          0.049117
# 3      neutral   neutral          0.045867
# 4     surprise  positive          0.107750
# 5      neutral   neutral          0.053517
# 6      neutral   neutral          0.051433
# 7      neutral   neutral          0.095233
# 8      neutral   neutral          0.016683
# 9      neutral   neutral          0.037350
# 10        fear  negative          0.033367
# 11     neutral   neutral          0.138317
# 12    surprise  positive          0.050750
# 13     neutral   neutral          0.052133
# 14    surprise  negative          0.041000
# 15     sadness  negative          0.036833
# 16    surprise  negative          0.079233
# 17        fear  negative          0.041683
# 18     neutral   neutral          0.019450
# 19     neutral   neutral          0.024250
# 20     neutral   neutral          0.033567
# 21     neutral   neutral          0.018050
# 22     neutral   neutral          0.024367
# 23         joy  positive          0.030767
# 24     sadness  negative          0.028517
# 25    surprise  negative          0.017333
# 26     neutral   neutral          0.036833
# 27     disgust  negative          0.079917
# 28     sadness  negative          0.044467
# 29     neutral   neutral          0.011133
# ...        ...       ...               ...
# 9959   neutral   neutral          0.027500
# 9960   neutral   neutral          0.029367
# 9961   neutral   neutral          0.028600
# 9962     anger  negative          0.029183
# 9963   neutral   neutral          0.114683
# 9964   neutral   neutral          0.035033
# 9965   neutral   neutral          0.010500
# 9966   neutral   neutral          0.023617
# 9967   sadness  negative          0.106350
# 9968   neutral   neutral          0.023200
# 9969   neutral   neutral          0.026233
# 9970   neutral   neutral          0.086183
# 9971   neutral   neutral          0.009050
# 9972       joy  positive          0.021567
# 9973   neutral   neutral          0.016667
# 9974   neutral   neutral          0.016667
# 9975  surprise  negative          0.045850
# 9976   disgust  negative          0.084083
# 9977   neutral   neutral          0.030567
# 9978   disgust  negative          0.054200
# 9979  surprise  negative          0.070900
# 9980   neutral   neutral          0.010533
# 9981   neutral   neutral          0.035000
# 9982   disgust  negative          0.143167
# 9983   disgust  negative          0.018750
# 9984   neutral   neutral          0.043767
# 9985   neutral   neutral          0.043083
# 9986  surprise  positive          0.050033
# 9987   neutral   neutral          0.031267
# 9988       joy  positive          0.061167
#
# [9979 rows x 5 columns]

# %%
dfa.isnull()
# Out:
#       Utterance  Speaker  Emotion  Sentiment  Duration_Minutes
# 0         False    False    False      False             False
# 1         False    False    False      False             False
# 2         False    False    False      False             False
# 3         False    False    False      False             False
# 4         False    False    False      False             False
# 5         False    False    False      False             False
# 6         False    False    False      False             False
# 7         False    False    False      False             False
# 8         False    False    False      False             False
# 9         False    False    False      False             False
# 10        False    False    False      False             False
# 11        False    False    False      False             False
# 12        False    False    False      False             False
# 13        False    False    False      False             False
# 14        False    False    False      False             False
# 15        False    False    False      False             False
# 16        False    False    False      False             False
# 17        False    False    False      False             False
# 18        False    False    False      False             False
# 19        False    False    False      False             False
# 20        False    False    False      False             False
# 21        False    False    False      False             False
# 22        False    False    False      False             False
# 23        False    False    False      False             False
# 24        False    False    False      False             False
# 25        False    False    False      False             False
# 26        False    False    False      False             False
# 27        False    False    False      False             False
# 28        False    False    False      False             False
# 29        False    False    False      False             False
# ...         ...      ...      ...        ...               ...
# 9959      False    False    False      False             False
# 9960      False    False    False      False             False
# 9961      False    False    False      False             False
# 9962      False    False    False      False             False
# 9963      False    False    False      False             False
# 9964      False    False    False      False             False
# 9965      False    False    False      False             False
# 9966      False    False    False      False             False
# 9967      False    False    False      False             False
# 9968      False    False    False      False             False
# 9969      False    False    False      False             False
# 9970      False    False    False      False             False
# 9971      False    False    False      False             False
# 9972      False    False    False      False             False
# 9973      False    False    False      False             False
# 9974      False    False    False      False             False
# 9975      False    False    False      False             False
# 9976      False    False    False      False             False
# 9977      False    False    False      False             False
# 9978      False    False    False      False             False
# 9979      False    False    False      False             False
# 9980      False    False    False      False             False
# 9981      False    False    False      False             False
# 9982      False    False    False      False             False
# 9983      False    False    False      False             False
# 9984      False    False    False      False             False
# 9985      False    False    False      False             False
# 9986      False    False    False      False             False
# 9987      False    False    False      False             False
# 9988      False    False    False      False             False
#
# [9979 rows x 5 columns]

# %%
dfa.isnull().sum()
# Out:
# Utterance           0
# Speaker             0
# Emotion             0
# Sentiment           0
# Duration_Minutes    0
# dtype: int64

# %%
dfa.isnull().sum().sum()
# Out:
# 0

# %%
dfa.columns
# Out:
# Index(['Utterance', 'Speaker', 'Emotion', 'Sentiment', 'Duration_Minutes'], dtype='object')

# %%
dfa.shape
# Out:
# (9979, 5)

# %%
unique_speakers = dfa['Speaker'].unique()

# %%
print(unique_speakers)
# Out:
# ['Chandler' 'The Interviewer' 'Joey' 'Rachel' 'Monica' 'Phoebe' 'Ross'
#  'Sergei' 'Customer' 'Jade' 'Mona' 'Charlie' 'Paleontologist'
#  'Professore Clerk' 'Caitlin' 'Nurse' 'Mr. Treeger' 'Carol'
#  'The Casting Director' 'Emily' 'Elizabeth' 'Paul' 'The Dry Cleaner'
#  'Joey and Chandler' 'Kate' 'The Director' 'Mr. Tribbiani' 'Guru Saj'
#  'Wayne' 'Richard' 'Dina' 'Bobby' 'Danny' 'Krista' 'Jill' 'Doug' 'Stevens'
#  'Bob' 'Mr. Franklin' 'Director' 'Janice' 'Tony' 'Peter'
#  'Ticket Counter Attendant' 'Dr. Long' 'Charlton Heston' 'Joshua' 'Nancy'
#  'Kim' 'Joanna' 'Cassie' 'Dr. Rhodes' 'Dr. Johnson' 'Kristen' 'Jester'
#  'Sarah' 'Pete' 'The Singing Man' 'Commercial' 'Mark' 'A Female Student'
#  'All' 'Cliff' 'Tag' 'Eric' 'Dr. Green' 'Mr. Heckles' 'Mr. Geller'
#  'Sophie' 'Singer' 'David' 'Hitchhiker' '1st Customer' '2nd Customer'
#  '3rd Customer' 'The Presenter' 'Policeman' 'Duncan' 'Jane' 'Message'
#  'Gary' 'Bonnie' 'Woman' 'Leslie' 'Isabella' "Joey's Hand Twin" 'Kiki'
#  'Joanne' 'Fireman No. 3' 'Susan' 'Mischa' 'The Assistant Director'
#  'Mrs. Geller' 'Emeril' 'Man' 'Jake' 'Tom' 'Lecturer' 'The Woman'
#  'Monica and Ross' 'The Vendor' 'Julio' 'Janine' 'Julie' 'Dr. Baldhara'
#  'Young Ethan' 'Dr. Leedbetter' 'Phoebe Sr.' 'Katie' 'Gunther' 'Earl'
#  'Barry' 'Robbie' 'Lydia' 'Bernice' 'Mindy' 'Robert' 'Issac' 'Chloe'
#  'Supervisor' 'Kathy' 'Voice' 'Stu' 'Tour Guide' 'Dr. Ledbetter'
#  'Mrs. Burgin' 'Mr. Burgin' 'Annabelle' 'Flight Attendant' 'Roger'
#  'Front Desk Clerk' 'Mr. Zelner' 'Student' 'Jason' 'Guy' 'Jim' 'Liam'
#  'Phoebe Sr' 'Stage Director' 'PBS Volunteer' 'Gary Collins' 'Carl'
#  'Phoebe and Rachel' 'The Cigarette Guy' 'Lorraine' 'an' 'Richard’s Date'
#  'Frank' 'Rachel and Phoebe' "Mona's Date" 'Ross and Joey' 'Mike'
#  'Dr. Miller' 'Both' 'Receptionist' 'Mrs. Green' 'Marc' 'Dana'
#  'The Fireman' 'Drunken Gambler' 'Raymond' 'Kristin' 'Monica and Phoebe'
#  'A Student' 'Hoshi' 'Ben' 'Teacher' 'Stephanie' 'Evil Bitch'
#  'Sick Bastard' 'Kyle' 'Nurse #1' 'Nurse #2' 'Dr. Stryker Ramoray'
#  'Helena' 'Angela' 'Steve' 'Airline Employee' 'Janitor' 'Mr. Posner'
#  'Mrs. Lynch' 'Paolo' 'Megan' 'Joey and Ross' 'Hombre Man' 'Dr. Zane'
#  'Alice' 'Russell' 'Chip' 'The Lurker' 'The Security Guard'
#  'The Librarian' 'The Head Librarian' 'Guy #1' 'Shelley' 'Girl' 'Leader'
#  'Dr. Wesley' 'Dr. Drake Remoray' 'Hope' 'Stranger' 'Hold Voice' 'Rick'
#  'Vince' 'Phoebe/Waitress' 'Joey/Drake' 'Rachel/actress' 'Mr. Waltham'
#  'Mrs. Waltham' 'Ms. McKenna' 'Fake Monica' 'Doctor' 'Boy in the Cape'
#  'Mrs. Chatracus' 'Paula' 'Burt' 'Ursula' 'Older Scientist'
#  'Another Tour Guide' 'Another Scientist' 'The Potential Roommate'
#  'Aunt Lillian' 'Ronni' 'Cecilia' 'Hotel Clerk' 'Casey' 'The Instructor'
#  'Jay Leno' 'The Smoking Woman' 'Trudie Styler' 'The Acting Teacher'
#  'Dr. Franzblau' 'Mrs. Tedlock' 'The Guys' 'The Museum Official'
#  'The Croupier' 'Jeannine' 'The Conductor' 'Woman On Train'
#  'The Food Critic' 'The Cooking Teacher' 'Waiter' 'Allesandro' 'Terry'
#  'Friend No. 2' 'Friend No. 1' 'Her-Friends' 'Estelle' 'Mrs. Tribbiani'
#  'Larry' 'Fireman No. 1' 'Fireman No. 2' 'Dr. Oberman' 'Gerston' 'Santos'
#  'Petrie' "Maitre d'" 'Melissa' 'Stanley' 'The Grip']

# %%
print(dfa['Speaker'].nunique())
# Out:
# 260

# %%
dfa['Speaker'].duplicated()
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14      False
# 15      False
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22      False
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 9959     True
# 9960     True
# 9961     True
# 9962     True
# 9963     True
# 9964    False
# 9965     True
# 9966     True
# 9967     True
# 9968     True
# 9969     True
# 9970     True
# 9971     True
# 9972     True
# 9973     True
# 9974     True
# 9975     True
# 9976     True
# 9977     True
# 9978     True
# 9979     True
# 9980     True
# 9981     True
# 9982     True
# 9983     True
# 9984     True
# 9985     True
# 9986     True
# 9987     True
# 9988     True
# Name: Speaker, Length: 9979, dtype: bool

# %%
dfa.shape
# Out:
# (9979, 5)

# %%
speaker=dfa.groupby('Speaker')

# %%
speaker.first().head()
# Out:
#                                                    Utterance   Emotion  \
# Speaker
# 1st Customer                       Everything was delicious!       joy
# 2nd Customer      It was. The duck in particular was superb.       joy
# 3rd Customer         Actually I do have one small complaint.   neutral
# A Female Student      Yeah, what's up with that girl Monica?   neutral
# A Student                   What’s happening to your accent?  surprise
#
#                  Sentiment  Duration_Minutes
# Speaker
# 1st Customer      positive          0.028533
# 2nd Customer      positive          0.042400
# 3rd Customer       neutral          0.041700
# A Female Student   neutral          0.032650
# A Student         negative          0.043083

# %%
speaker.get_group('A Student')
# Out:
#                              Utterance   Emotion Sentiment  Duration_Minutes
# 4994  What’s happening to your accent?  surprise  negative          0.043083

# %%
speaker.get_group('Chandler')
# Out:
#                                               Utterance   Emotion Sentiment  \
# 0     also I was the point person on my company’s tr...   neutral   neutral
# 2                               That I did. That I did.   neutral   neutral
# 4                                My duties?  All right.  surprise  positive
# 6                                                I see.   neutral   neutral
# 8                                         Good to know.   neutral   neutral
# 10                               No don’t I beg of you!      fear  negative
# 12                                             Really?!  surprise  positive
# 21                                            Hey, Mon.   neutral   neutral
# 23                                           Do I ever.       joy  positive
# 25                                              No way!  surprise  negative
# 27        Just coffee! Where are we gonna hang out now?   disgust  negative
# 29                                    Can I get a beer.   neutral   neutral
# 31                                          You betcha!       joy  positive
# 33                                   Um-mm, yeah right!       joy  positive
# 35                                   What, what, what?!  surprise  negative
# 62                  Good job Joe! Well done! Top notch!       joy  positive
# 64                                      Oh-ho-ho, yeah!       joy  positive
# 66                          The whole thing! Can we go?   neutral   neutral
# 68    I love the specifics, the specifics were the b...       joy  positive
# 70    I was surprised to see a kangaroo in a World W...  surprise  negative
# 76                                            Don’t go!   sadness  negative
# 77                                           I’m sorry.   sadness  negative
# 78                                        I’m so sorry!   sadness  negative
# 79                                                Look!  surprise  negative
# 80                                This guy fell asleep!     anger  negative
# 81                                  He fell asleep too!     anger  negative
# 82                                       Be mad at him!     anger  negative
# 83                               Or, call an ambulance.     anger  negative
# 88                           Okay, that’s enough honey!   neutral   neutral
# 90                                   Great! Okay, here.       joy  positive
# ...                                                 ...       ...       ...
# 9789  Right, calm down, O'Mally. I'll slip him some ...   neutral   neutral
# 9791                              Hey, I can be smooth.   neutral   neutral
# 9792  Listen, we're a little bit in a hurry, so, if ...   neutral   neutral
# 9794                                              Okay.   neutral   neutral
# 9802                                 I can blow dry it.   neutral   neutral
# 9803                               I can put gel on it.   neutral   neutral
# 9804  It doesn’t matter, I still wind up with this l...   neutral   neutral
# 9805                                  It’s so annoying.   disgust  negative
# 9806                                   Does it bug you?   sadness  negative
# 9808           Is there any chance you didn’t see that?   neutral   neutral
# 9825                         Well, I feel like a snack!       joy  positive
# 9827                         Oh no thanks. I don’t like   neutral   neutral
# 9829  Well it’s just my entire family was run out of...   sadness  negative
# 9868  Well, my Grandfather was Swedish and my Grandm...       joy  positive
# 9870  Y'know that is a popular opinion today I must ...   neutral   neutral
# 9872  The weirdest thing happened at the coffee hous...  surprise  negative
# 9874    I'm telling you I think Phoebe thinks I'm foxy.       joy  positive
# 9876                                                Ow!  surprise  positive
# 9878             Oh, y'know I-I can't hear that enough.     anger  negative
# 9880  No, I didn't misunderstand, okay? She was all ...     anger  negative
# 9882                    Well it's not flexed right now!     anger  negative
# 9919           Excuse me, Doug?  Hey there sports fan!!       joy  positive
# 9934             But you found the keys to his clothes?   neutral   neutral
# 9941  I’m not even getting married! Okay, this is a ...   neutral   neutral
# 9944                         I’m not even… I’m not even   neutral   neutral
# 9971                                               Hey.   neutral   neutral
# 9974                               I broke up with her.   neutral   neutral
# 9976  They were huge. When she sneezed, bats flew ou...   disgust  negative
# 9978  I'm tellin' you, she leaned back; I could see ...   disgust  negative
# 9984                                         You or me?   neutral   neutral
#
#       Duration_Minutes
# 0             0.094533
# 2             0.049117
# 4             0.107750
# 6             0.051433
# 8             0.016683
# 10            0.033367
# 12            0.050750
# 21            0.018050
# 23            0.030767
# 25            0.017333
# 27            0.079917
# 29            0.011133
# 31            0.013533
# 33            0.020150
# 35            0.018867
# 62            0.053517
# 64            0.028417
# 66            0.043100
# 68            0.067433
# 70            0.093850
# 76            0.010033
# 77            0.012033
# 78            0.021767
# 79            0.007700
# 80            0.019700
# 81            0.010433
# 82            0.014883
# 83            0.031283
# 88            0.022233
# 90            0.047250
# ...                ...
# 9789          0.145967
# 9791          0.037533
# 9792          0.082017
# 9794          0.027717
# 9802          0.020367
# 9803          0.030500
# 9804          0.109817
# 9805          0.059767
# 9806          0.013367
# 9808          0.050033
# 9825          0.036133
# 9827          0.068817
# 9829          0.113283
# 9868          0.094517
# 9870          0.051433
# 9872          0.074367
# 9874          0.033350
# 9876          0.015900
# 9878          0.047950
# 9880          0.084800
# 9882          0.043783
# 9919          0.098700
# 9934          0.047250
# 9941          0.083400
# 9944          0.032067
# 9971          0.009050
# 9974          0.016667
# 9976          0.084083
# 9978          0.054200
# 9984          0.043767
#
# [1281 rows x 4 columns]

# %%
 dfa['Speaker'].drop_duplicates(inplace=True)

# %%
dfa.shape
# Out:
# (9979, 5)

# %%
speaker=dfa.groupby('Speaker')

# %%
speaker.get_group('Chandler')
# Out:
#                                            Utterance   Speaker  Emotion  \
# 0  also I was the point person on my company’s tr...  Chandler  neutral
#
#   Sentiment  Duration_Minutes
# 0   neutral          0.094533

# %%
speaker=dfa['Speaker'].value_counts()
print(speaker.head())
# Out:
# Fireman No. 1     1
# Mrs. Waltham      1
# Issac             1
# Kate              1
# Rachel/actress    1
# Name: Speaker, dtype: int64

# %%
dfa.head()
# Out:
#                                            Utterance          Speaker  \
# 0  also I was the point person on my company’s tr...         Chandler
# 1                   You must’ve had your hands full.  The Interviewer
# 2                            That I did. That I did.         Chandler
# 3      So let’s talk a little bit about your duties.  The Interviewer
# 4                             My duties?  All right.         Chandler
#
#     Emotion Sentiment  Duration_Minutes
# 0   neutral   neutral          0.094533
# 1   neutral   neutral          0.025033
# 2   neutral   neutral          0.049117
# 3   neutral   neutral          0.045867
# 4  surprise  positive          0.107750

# %%
dfa['Speaker'].nunique()
# Out:
# 260

# %%
dfa['Speaker']
# Out:
# 0                   Chandler
# 1            The Interviewer
# 14                      Joey
# 15                    Rachel
# 22                    Monica
# 34                    Phoebe
# 44                      Ross
# 61                    Sergei
# 89                  Customer
# 94                      Jade
# 135                     Mona
# 146                  Charlie
# 157           Paleontologist
# 160         Professore Clerk
# 181                  Caitlin
# 230                    Nurse
# 251              Mr. Treeger
# 267                    Carol
# 269     The Casting Director
# 285                    Emily
# 302                Elizabeth
# 304                     Paul
# 319          The Dry Cleaner
# 322        Joey and Chandler
# 394                     Kate
# 401             The Director
# 428            Mr. Tribbiani
# 445                 Guru Saj
# 517                    Wayne
# 556                  Richard
#                 ...
# 8675      The Acting Teacher
# 8708           Dr. Franzblau
# 8796            Mrs. Tedlock
# 8832                The Guys
# 8895     The Museum Official
# 8911            The Croupier
# 8982                Jeannine
# 8997           The Conductor
# 8999          Woman On Train
# 9048         The Food Critic
# 9055     The Cooking Teacher
# 9083                  Waiter
# 9186              Allesandro
# 9331                   Terry
# 9361            Friend No. 2
# 9365            Friend No. 1
# 9367             Her-Friends
# 9418                 Estelle
# 9556          Mrs. Tribbiani
# 9596                   Larry
# 9640           Fireman No. 1
# 9641           Fireman No. 2
# 9696             Dr. Oberman
# 9715                 Gerston
# 9716                  Santos
# 9717                  Petrie
# 9782               Maitre d'
# 9890                 Melissa
# 9948                 Stanley
# 9964                The Grip
# Name: Speaker, Length: 260, dtype: object

# %%
Emotion=dfa.groupby('Emotion')

# %%
Emotion.first()
# Out:
#                                                   Utterance   Speaker  \
# Emotion
# anger                  Oh no-no-no, give me some specifics.      Joey
# disgust       Just coffee! Where are we gonna hang out now?  Chandler
# fear                                 No don’t I beg of you!  Chandler
# joy                                              Do I ever.  Chandler
# neutral   also I was the point person on my company’s tr...  Chandler
# sadness                                You know? Forget it!    Rachel
# surprise                             My duties?  All right.  Chandler
#
#          Sentiment  Duration_Minutes
# Emotion
# anger     negative          0.039633
# disgust   negative          0.079917
# fear      negative          0.033367
# joy       positive          0.030767
# neutral    neutral          0.094533
# sadness   negative          0.036833
# surprise  positive          0.107750

# %%
Emotion.size()
# Out:
# Emotion
# anger       1108
# disgust      271
# fear         268
# joy         1738
# neutral     4708
# sadness      683
# surprise    1203
# dtype: int64

# %%
Emotion.agg('max')
# Out:
#                                                   Utterance  \
# Emotion
# anger                              if you don’t get that...
# disgust   so we finally get to the top of the mountain a...
# fear      ‘Cause I kinda all ready told her uh, it was, ...
# joy                                                   ‘Kay!
# neutral                                    ‘Sup? ‘Sup dude?
# sadness                   is for me not to see you anymore.
# surprise                          oooooooooooooohhhhhhhhhhh
#
#                     Speaker Sentiment  Duration_Minutes
# Emotion
# anger                 Woman  negative          0.299600
# disgust               Woman  negative          0.382317
# fear      The Smoking Woman  negative          0.241883
# joy                      an  positive          0.684000
# neutral         Young Ethan   neutral          0.404550
# sadness         Young Ethan  negative          0.319050
# surprise                Tom  positive          0.292633

# %%
Emotion.agg('count')
# Out:
#           Utterance  Speaker  Sentiment  Duration_Minutes
# Emotion
# anger          1108     1108       1108              1108
# disgust         271      271        271               271
# fear            268      268        268               268
# joy            1738     1738       1738              1738
# neutral        4708     4708       4708              4708
# sadness         683      683        683               683
# surprise       1203     1203       1203              1203

# %%
Emotion.nunique()
# Out:
#           Utterance  Speaker  Sentiment  Duration_Minutes
# Emotion
# anger          1065       82          1               536
# disgust         270       32          1               194
# fear            264       32          1               207
# joy            1589      121          1               689
# neutral        4211      209          1              1135
# sadness         668       55          1               382
# surprise       1006       87          2               517

# %%
Emotion.groups
# Out:
# {'anger': Int64Index([  67,   71,   72,   73,   80,   81,   82,   83,   85,  106,
#              ...
#              9864, 9878, 9880, 9882, 9888, 9940, 9942, 9945, 9957, 9962],
#             dtype='int64', length=1108),
#  'disgust': Int64Index([  27,  105,  125,  127,  133,  170,  223,  226,  229,  365,
#              ...
#              9734, 9805, 9807, 9849, 9850, 9889, 9976, 9978, 9982, 9983],
#             dtype='int64', length=271),
#  'fear': Int64Index([  10,   17,  129,  132,  178,  180,  191,  195,  250,  285,
#              ...
#              9452, 9456, 9458, 9459, 9515, 9552, 9736, 9762, 9768, 9860],
#             dtype='int64', length=268),
#  'joy': Int64Index([  23,   31,   33,   44,   51,   52,   53,   62,   64,   68,
#              ...
#              9910, 9919, 9920, 9928, 9935, 9938, 9946, 9947, 9972, 9988],
#             dtype='int64', length=1738),
#  'neutral': Int64Index([   0,    1,    2,    3,    5,    6,    7,    8,    9,   11,
#              ...
#              9970, 9971, 9973, 9974, 9977, 9980, 9981, 9984, 9985, 9987],
#             dtype='int64', length=4708),
#  'sadness': Int64Index([  15,   24,   28,   41,   54,   76,   77,   78,  148,  150,
#              ...
#              9884, 9885, 9886, 9912, 9914, 9915, 9948, 9950, 9955, 9967],
#             dtype='int64', length=683),
#  'surprise': Int64Index([   4,   12,   14,   16,   25,   34,   35,   36,   40,   43,
#              ...
#              9913, 9929, 9936, 9939, 9949, 9951, 9953, 9975, 9979, 9986],
#             dtype='int64', length=1203)}

# %%
dfa.groupby(['Emotion','Sentiment'])

# %%
sentiment=dfa.groupby('Sentiment')
